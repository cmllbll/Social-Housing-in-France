# %%
import pandas as pd

# %%
dfd = pd.read_csv(r'C:\Users\arceb\Desktop\Stage\BDD/demandeurs_IDF__revenus.csv')

# %%
dfd
# Out:
#          Unnamed: 0       Numéro Unique  Ressources mensuelles\n  \
# 0                 0  0010216061927GDPUB                    908.0
# 1                 1  001021707657411126                   1239.0
# 2                 2  0010417079507GDPUB                   1000.0
# 3                 3  001071606857001033                   1570.0
# 4                 4  001071606857001033                   1570.0
# ...             ...                 ...                      ...
# 1285446     1285446  974081715046411487                   1027.0
# 1285447     1285447  974101613022611484                   1240.0
# 1285448     1285448  974111613236511483                   1650.0
# 1285449     1285449  9741217157605GDPUB                    475.0
# 1285450     1285450               65838                      NaN
#
#                        Type de ressource\n  Montant par type de ressource\n
# 0                                 Retraite                            908.0
# ...

# %%
#bdd=dfd
#bdd.drop_duplicates(subset ="Numéro Unique", keep = 'first', inplace=True)
#bdd

# %%
dfd=dfd.rename(columns={'Type de ressource\n': 'Type'})

# %%
dfd
# Out:
#          Unnamed: 0       Numéro Unique  Ressources mensuelles\n  \
# 0                 0  0010216061927GDPUB                    908.0
# 1                 1  001021707657411126                   1239.0
# 2                 2  0010417079507GDPUB                   1000.0
# 3                 3  001071606857001033                   1570.0
# 4                 4  001071606857001033                   1570.0
# ...             ...                 ...                      ...
# 1285446     1285446  974081715046411487                   1027.0
# 1285447     1285447  974101613022611484                   1240.0
# 1285448     1285448  974111613236511483                   1650.0
# 1285449     1285449  9741217157605GDPUB                    475.0
# 1285450     1285450               65838                      NaN
#
#                                       Type  Montant par type de ressource\n
# 0                                 Retraite                            908.0
# ...

# %%
values=["Retraite", "Allocation chômage / indemnités", "Salaire ou revenu d'activité", "Pension alimentaire reçue", "Autres (hors APL ou AL)", "Pension d\'invalidité"]
filtered_df = dfd[dfd.Type.isin(values)]
filtered_df
# Out:
#          Unnamed: 0       Numéro Unique  Ressources mensuelles\n  \
# 0                 0  0010216061927GDPUB                    908.0
# 1                 1  001021707657411126                   1239.0
# 2                 2  0010417079507GDPUB                   1000.0
# 3                 3  001071606857001033                   1570.0
# 4                 4  001071606857001033                   1570.0
# ...             ...                 ...                      ...
# 1285443     1285443  974051714578111487                    367.0
# 1285445     1285445  974081715046411487                   1027.0
# 1285446     1285446  974081715046411487                   1027.0
# 1285447     1285447  974101613022611484                   1240.0
# 1285448     1285448  974111613236511483                   1650.0
#
#                                     Type  Montant par type de ressource\n
# 0                               Retraite                            908.0
# ...

# %%
filtered_df['Revenu imposable']=''
filtered_df
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_27452\1670114371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Revenu imposable']=''
#          Unnamed: 0       Numéro Unique  Ressources mensuelles\n  \
# 0                 0  0010216061927GDPUB                    908.0
# 1                 1  001021707657411126                   1239.0
# 2                 2  0010417079507GDPUB                   1000.0
# 3                 3  001071606857001033                   1570.0
# 4                 4  001071606857001033                   1570.0
# ...             ...                 ...                      ...
# 1285443     1285443  974051714578111487                    367.0
# ...

# %%
filtered_df.reset_index(inplace=True, drop=True)

# %%
range(453438)
# Out:
# range(0, 453438)

# %%
filtered_df['Revenu imposable'][0] = filtered_df.loc[[0,1], ['Montant par type de ressource\n']].sum(axis=0)
#df.loc[1 : 3,['X' , 'Y']].sum(axis = 1)
filtered_df
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_27452\2988568266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Revenu imposable'][0] = filtered_df.loc[[0,1], ['Montant par type de ressource\n']].sum(axis=0)
#         Unnamed: 0       Numéro Unique  Ressources mensuelles\n  \
# 0                0  0010216061927GDPUB                    908.0
# 1                1  001021707657411126                   1239.0
# 2                2  0010417079507GDPUB                   1000.0
# 3                3  001071606857001033                   1570.0
# 4                5  001081708354301071                   2000.0
# ...            ...                 ...                      ...
# 453434     1285442  9740317140152GDPUB                    952.0
# ...

# %%
filtered_df['Numéro Unique'][1]
# Out:
# '001021707657411126'

# %%
for i in range(0,453437):

    if filtered_df['Numéro Unique'][i] == filtered_df['Numéro Unique'][i+1] :
        filtered_df['Revenu imposable'][i] = filtered_df.loc[[i,i+1], ['Montant par type de ressource\n']].sum(axis=0)

    else:
#filtered_df['Numéro Unique'][i] != filtered_df['Numéro Unique'][i+1] :
        filtered_df['Revenu imposable'][i] = filtered_df['Montant par type de ressource\n'][i]
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_27452\2144551415.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Revenu imposable'][i] = filtered_df['Montant par type de ressource\n'][i]
# C:\Users\arceb\AppData\Local\Temp\ipykernel_27452\2144551415.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Revenu imposable'][i] = filtered_df.loc[[i,i+1], ['Montant par type de ressource\n']].sum(axis=0)
# C:\Users\arceb\AppData\Local\Temp\ipykernel_27452\2144551415.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
filtered_df
# Out:
#         Unnamed: 0       Numéro Unique  Ressources mensuelles\n  \
# 0                0  0010216061927GDPUB                    908.0
# 1                1  001021707657411126                   1239.0
# 2                2  0010417079507GDPUB                   1000.0
# 3                3  001071606857001033                   1570.0
# 4                4  001071606857001033                   1570.0
# ...            ...                 ...                      ...
# 786262     1285443  974051714578111487                    367.0
# 786263     1285445  974081715046411487                   1027.0
# 786264     1285446  974081715046411487                   1027.0
# 786265     1285447  974101613022611484                   1240.0
# 786266     1285448  974111613236511483                   1650.0
#
#                                    Type  Montant par type de ressource\n  \
# 0                              Retraite                            908.0
# ...

# %%
base
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 5          False
#            ...
# 1285445    False
# 1285447     True
# 1285448    False
# 1285449    False
# 1285450    False
# Name: Type de ressource\n, Length: 704847, dtype: bool
