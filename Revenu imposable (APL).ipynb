# %%
import pandas as pd

# %%
df = pd.DataFrame(pd.read_excel(r'C:\Users\arceb\PycharmProjects\pythonProject/Tableau_RI-PFS_1.xlsx'))

# %%
df
# Out:
#    Tranches de RI / Tranches de PFS   Entre 0 et 50 €  Entre 50 et 100€  \
# 0                    Entre 0 et 50 €            670.0              33.0
# 1                   Entre 50 et 100€             35.0               1.0
# 2                  Entre 100 et 150€             78.0               3.0
# 3                  Entre 150 et 200€             82.0               2.0
# 4                  Entre 200 et 250€             96.0               4.0
# 5                  Entre 250 et 300€            125.0               2.0
# 6                  Entre 300 et 350€            191.0               2.0
# 7                  Entre 350 et 400€            173.0              10.0
# 8                  Entre 400 et 450€            227.0               7.0
# 9                  Entre 450 et 500€            744.0               7.0
# 10                 Entre 500 et 550€           1057.0              12.0
# 11                 Entre 550 et 600€            394.0              11.0
# ...
