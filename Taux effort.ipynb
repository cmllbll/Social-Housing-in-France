# %%
import numpy as np
import pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\arceb\PycharmProjects\pythonProject/Paris_final.csv', index_col = 0)
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_7844\1945794923.py:1: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'C:\Users\arceb\PycharmProjects\pythonProject/Paris_final.csv', index_col = 0)

# %%
df
# Out:
#              Numéro Unique  RM Moyennes  \
# 0       111011473621594041       1094.0
# 1       111011596527675056       1127.0
# 2       111011624892175056       1501.0
# 3       1110117567829GDPUB        674.0
# 4       1110117576292AL018       1410.0
# ...                    ...          ...
# 181616  175120708787700002        433.0
# 181617  175120725745300002       2415.0
# 181618  175120901070000002       1225.0
# 181619  175121022516400002       1535.0
# 181620  211011233353775B02        924.0
#
#         Ressources imposables mensuelles moyennes (RI)  \
# 0                                                105.0
# 1                                               1127.0
# 2                                                  0.0
# 3                                                  0.0
# 4                                               1410.0
# ...                                                ...
# 181616                                             0.0
# 181617                                          2415.0
# 181618                                           816.0
# 181619                                          1535.0
# 181620                                             0.0
#
#         Prestations familiales et sociales mensuelles moyennes (PFS)  \
# 0                                                   989.0
# 1                                                     0.0
# 2                                                  1501.0
# 3                                                   674.0
# 4                                                     0.0
# ...                                                   ...
# 181616                                              433.0
# 181617                                                0.0
# 181618                                              409.0
# 181619                                                0.0
# 181620                                              924.0
#
#         Ri + PFS            région Date création demande  Age demandeur  \
# 0         1094.0            Alsace            2014-01-10           43.0
# 1         1127.0            Alsace            2015-01-26           24.0
# 2         1501.0            Alsace            2016-01-20           47.0
# 3          674.0            Alsace            2017-01-14           27.0
# 4         1410.0            Alsace            2017-01-25           30.0
# ...          ...               ...                   ...            ...
# 181616     433.0  Pays de la Loire            2007-12-05           37.0
# 181617    2415.0          Picardie            2007-12-17           54.0
# 181618    1225.0          Picardie            2009-12-15           29.0
# 181619    1535.0  Pays de la Loire            2010-12-20           72.0
# 181620     924.0          Picardie            2009-09-03           49.0
#
#        Situation familiale Code département logement actuel  ...  \
# 0                Marié (e)                             68.0  ...
# 1              Célibataire                             67.0  ...
# 2                Marié (e)                             67.0  ...
# 3              Divorcé (e)                             68.0  ...
# 4             Concubin (e)                             67.0  ...
# ...                    ...                              ...  ...
# 181616         Célibataire                             44.0  ...
# 181617         Célibataire                             60.0  ...
# 181618         Célibataire                             60.0  ...
# 181619         Divorcé (e)                             49.0  ...
# 181620         Célibataire                             60.0  ...
#
#        RFR du foyer, année n-2 Code Géographique   Commune logement souhaité  \
# 0                          NaN             75056                       Paris
# 1                      10817.0             75056   Paris 5ème arrondissement
# 2                          NaN             75056                       Paris
# 3                          NaN             75056  Paris 13ème arrondissement
# 4                          NaN             75056   Paris 3ème arrondissement
# ...                        ...               ...                         ...
# 181616                     0.0             75056    Paris 1er arrondissement
# 181617                 36855.0             75056   Paris 5ème arrondissement
# 181618                     0.0             75056                       Paris
# 181619                 14688.0             75056   Paris 5ème arrondissement
# 181620                     0.0             75056                       Paris
#
#        Montant maxi (loyer+charges) supportable  Sexe demandeur\n  \
# 0                                         650.0                 M
# 1                                         520.0                 M
# 2                                         900.0                 M
# 3                                         800.0                 F
# 4                                        1250.0                 M
# ...                                         ...               ...
# 181616                                    350.0                 M
# 181617                                    500.0                 M
# 181618                                    450.0                 F
# 181619                                    700.0                 F
# 181620                                    450.0                 F
#
#         Nationalité demandeur\n  Autre logement dé\ntenu demandeur\n  \
# 0         Hors Union Européenne                                  Non
# 1                     Française                                  Non
# 2         Hors Union Européenne                                  Non
# 3                     Française                                  Non
# 4                     Française                                  Non
# ...                         ...                                  ...
# 181616    Hors Union Européenne                                  Non
# 181617                Française                                  Non
# 181618                Française                                  Non
# 181619                Française                                  Non
# 181620                Française                                  Non
#
#        Nb de personnes handicapees Libellé de la commune  \
# 0                              0.0                 Paris
# 1                              0.0                 Paris
# 2                              0.0                 Paris
# 3                              0.0                 Paris
# 4                              0.0                 Paris
# ...                            ...                   ...
# 181616                         0.0                 Paris
# 181617                         0.0                 Paris
# 181618                         0.0                 Paris
# 181619                         0.0                 Paris
# 181620                         1.0                 Paris
#
#        Zonage I/II/III\nArrêté du 17 mars 1978 relatif au classement des communes par zones geographiques
# 0                                                  01 bis
# 1                                                  01 bis
# 2                                                  01 bis
# 3                                                  01 bis
# 4                                                  01 bis
# ...                                                   ...
# 181616                                             01 bis
# 181617                                             01 bis
# 181618                                             01 bis
# 181619                                             01 bis
# 181620                                             01 bis
#
# [181621 rows x 33 columns]

# %%
def plafond_loyer(compo_foyer):
    if compo_foyer=="Personne seule":
        return 295.05
    elif compo_foyer=="Au moins 2 cotitulaires":
        return 355.85
    elif (compo_foyer=="Au moins 2 cotitulaires avec une personne à charge" or compo_foyer=="Pers.seule avec 1 pers. à charge") :
        return 402.18
    elif (compo_foyer=="Pers.seule avec 2 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 2 personnes à charge"):
        return 402.18+58.34
    elif (compo_foyer=="Pers.seule avec 3 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 3 personnes à charge"):
        return 402.18+58.34+58.34
    elif (compo_foyer=="Pers.seule avec 4 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 4 personnes à charge"):
        return 402.18+58.34+58.34+58.34
    elif (compo_foyer=="Pers.seule avec 5 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 5 personnes à charge"):
        return 402.18+58.34+58.34+58.34+58.34
    elif (compo_foyer=="Personne seule avec 6 pers. à charge ou plus" or compo_foyer=="Au moins 2 cotitulaires avec 6 personnes à charge ou plus"):
        return 402.18+58.34+58.34+58.34+58.34+58.34

# %%
df['Plafond loyer'] = df['Composition foyer demandeur'].apply(plafond_loyer)

# %%
base
# Out:
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer
# 0              295.05
# 1              295.05
# 2              295.05
# 3              355.85
# 4              295.05
# ...               ...
# 153709         355.85
# 153710         295.05
# 153711         295.05
# 153712         460.52
# 153713         402.18
#
# [153714 rows x 8 columns]

# %%
base['Loyer éligible']=base[['Montant loyer mensuel du logement attribué\n','Plafond loyer']].min(axis=1)
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_7844\3744413431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['Loyer éligible']=base[['Montant loyer mensuel du logement attribué\n','Plafond loyer']].min(axis=1)

# %%
base
# Out:
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
# [153714 rows x 9 columns]

# %%
def charges(compo_foyer):
    if compo_foyer=="Personne seule":
        return 53.67
    elif compo_foyer=="Au moins 2 cotitulaires":
        return 53.67
    elif (compo_foyer=="Au moins 2 cotitulaires avec une personne à charge" or compo_foyer=="Pers.seule avec 1 pers. à charge") :
        return 53.67+12.16
    elif (compo_foyer=="Pers.seule avec 2 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 2 personnes à charge"):
        return 53.67+12.16+12.16
    elif (compo_foyer=="Pers.seule avec 3 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 3 personnes à charge"):
        return 53.67+12.16+12.16+12.16
    elif (compo_foyer=="Pers.seule avec 4 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 4 personnes à charge"):
        return 53.67+12.16+12.16+12.16+12.16
    elif (compo_foyer=="Pers.seule avec 5 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 5 personnes à charge"):
        return 53.67+12.16+12.16+12.16+12.16+12.16
    elif (compo_foyer=="Personne seule avec 6 pers. à charge ou plus" or compo_foyer=="Au moins 2 cotitulaires avec 6 personnes à charge ou plus"):
        return 53.67+12.16+12.16+12.16+12.16+12.16+12.16

# %%
base['Montant forfaitaire au titre des charges'] = base['Composition foyer demandeur'].apply(charges)
base
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_7844\3050364869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['Montant forfaitaire au titre des charges'] = base['Composition foyer demandeur'].apply(charges)
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges
# 0                                          53.67
# 1                                          53.67
# 2                                          53.67
# 3                                          53.67
# 4                                          53.67
# ...                                          ...
# 153709                                     53.67
# 153710                                     53.67
# 153711                                     53.67
# 153712                                     77.99
# 153713                                     65.83
#
# [153714 rows x 10 columns]

# %%
imp = pd.read_csv(r'RI_PFS_IDF.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 imp = pd.read_csv(r'RI_PFS_IDF.csv')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'RI_PFS_IDF.csv'

# %%
base= base.merge(imp, on='Numéro Unique', how='inner')
base
# Out:
#        Montant maxi (loyer+charges) supportable  \
# 0                                         300.0
# 1                                         400.0
# 2                                         300.0
# 3                                         700.0
# 4                                        1000.0
# ...                                         ...
# 60072                                       NaN
# 60073                                       NaN
# 60074                                       NaN
# 60075                                       NaN
# 60076                                       NaN
#
#        Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                               556.0                                 1.0
# 1                              1763.0                                 1.0
# 2                              1281.0                                 1.0
# 3                              3535.0                                 1.5
# 4                              3144.0                                 1.0
# ...                               ...                                 ...
# 60072                          1708.0                                 1.0
# 60073                          1279.0                                 1.9
# 60074                          1776.0                                 1.3
# 60075                          1273.0                                 1.0
# 60076                           759.0                                 1.0
#
#        Loyer montant mensuel       Composition foyer demandeur  \
# 0                      308.0                    Personne seule
# 1                      800.0                    Personne seule
# 2                      802.0                    Personne seule
# 3                      694.0           Au moins 2 cotitulaires
# 4                      878.0                    Personne seule
# ...                      ...                               ...
# 60072                  126.0                    Personne seule
# 60073                    0.0  Pers.seule avec 3 pers. à charge
# 60074                  328.0  Pers.seule avec 1 pers. à charge
# 60075                  450.0                    Personne seule
# 60076                  412.0                    Personne seule
#
#        Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                 0  175037900427000002
# 1                                               298  175118000728300002
# 2                                               372  211048217550092024
# 3                                               810  175108301617300002
# 4                                               626  175128420982700002
# ...                                             ...                 ...
# 60072                                           221  111011889159510122
# 60073                                           546  111011889407777067
# 60074                                           395  111011890348275B06
# 60075                                           270  111011891211794B02
# 60076                                           365  111011892001610103
#
#        Plafond loyer  Loyer éligible  \
# 0             295.05            0.00
# 1             295.05          295.05
# 2             295.05          295.05
# 3             355.85          355.85
# 4             295.05          295.05
# ...              ...             ...
# 60072         295.05          221.00
# 60073         518.86          518.86
# 60074         402.18          395.00
# 60075         295.05          270.00
# 60076         295.05          295.05
#
#        Montant forfaitaire au titre des charges  Unnamed: 0  RM Moyennes  \
# 0                                         53.67      130681        556.0
# 1                                         53.67      143374       1763.0
# 2                                         53.67      402468       1281.0
# 3                                         53.67      141654       1371.0
# 4                                         53.67      145079       3144.0
# ...                                         ...         ...          ...
# 60072                                     53.67      160165       1708.0
# 60073                                     90.15      160166       1279.0
# 60074                                     65.83       12689       1776.0
# 60075                                     53.67      546378       1273.0
# 60076                                     53.67      160168        759.0
#
#        Ressources imposables mensuelles moyennes (RI)  \
# 0                                               438.0
# 1                                              1763.0
# 2                                              1281.0
# 3                                              1371.0
# 4                                              3144.0
# ...                                               ...
# 60072                                          2220.0
# 60073                                             0.0
# 60074                                          1445.0
# 60075                                          1473.0
# 60076                                           759.0
#
#        Prestations familiales et sociales mensuelles moyennes (PFS)  Ri + PFS
# 0                                                  118.0                556.0
# 1                                                    0.0               1763.0
# 2                                                    0.0               1281.0
# 3                                                    0.0               1371.0
# 4                                                    0.0               3144.0
# ...                                                  ...                  ...
# 60072                                                0.0               2220.0
# 60073                                             1279.0               1279.0
# 60074                                              331.0               1776.0
# 60075                                                0.0               1473.0
# 60076                                                0.0                759.0
#
# [60077 rows x 15 columns]

# %%
base["Ressources annuels ménage"]=(base['Ressources imposables mensuelles moyennes (RI)']*0.9)*12
base
# Out:
#        Montant maxi (loyer+charges) supportable  \
# 0                                         300.0
# 1                                         400.0
# 2                                         300.0
# 3                                         700.0
# 4                                        1000.0
# ...                                         ...
# 60072                                       NaN
# 60073                                       NaN
# 60074                                       NaN
# 60075                                       NaN
# 60076                                       NaN
#
#        Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                               556.0                                 1.0
# 1                              1763.0                                 1.0
# 2                              1281.0                                 1.0
# 3                              3535.0                                 1.5
# 4                              3144.0                                 1.0
# ...                               ...                                 ...
# 60072                          1708.0                                 1.0
# 60073                          1279.0                                 1.9
# 60074                          1776.0                                 1.3
# 60075                          1273.0                                 1.0
# 60076                           759.0                                 1.0
#
#        Loyer montant mensuel       Composition foyer demandeur  \
# 0                      308.0                    Personne seule
# 1                      800.0                    Personne seule
# 2                      802.0                    Personne seule
# 3                      694.0           Au moins 2 cotitulaires
# 4                      878.0                    Personne seule
# ...                      ...                               ...
# 60072                  126.0                    Personne seule
# 60073                    0.0  Pers.seule avec 3 pers. à charge
# 60074                  328.0  Pers.seule avec 1 pers. à charge
# 60075                  450.0                    Personne seule
# 60076                  412.0                    Personne seule
#
#        Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                 0  175037900427000002
# 1                                               298  175118000728300002
# 2                                               372  211048217550092024
# 3                                               810  175108301617300002
# 4                                               626  175128420982700002
# ...                                             ...                 ...
# 60072                                           221  111011889159510122
# 60073                                           546  111011889407777067
# 60074                                           395  111011890348275B06
# 60075                                           270  111011891211794B02
# 60076                                           365  111011892001610103
#
#        Plafond loyer  Loyer éligible  \
# 0             295.05            0.00
# 1             295.05          295.05
# 2             295.05          295.05
# 3             355.85          355.85
# 4             295.05          295.05
# ...              ...             ...
# 60072         295.05          221.00
# 60073         518.86          518.86
# 60074         402.18          395.00
# 60075         295.05          270.00
# 60076         295.05          295.05
#
#        Montant forfaitaire au titre des charges  Unnamed: 0  RM Moyennes  \
# 0                                         53.67      130681        556.0
# 1                                         53.67      143374       1763.0
# 2                                         53.67      402468       1281.0
# 3                                         53.67      141654       1371.0
# 4                                         53.67      145079       3144.0
# ...                                         ...         ...          ...
# 60072                                     53.67      160165       1708.0
# 60073                                     90.15      160166       1279.0
# 60074                                     65.83       12689       1776.0
# 60075                                     53.67      546378       1273.0
# 60076                                     53.67      160168        759.0
#
#        Ressources imposables mensuelles moyennes (RI)  \
# 0                                               438.0
# 1                                              1763.0
# 2                                              1281.0
# 3                                              1371.0
# 4                                              3144.0
# ...                                               ...
# 60072                                          2220.0
# 60073                                             0.0
# 60074                                          1445.0
# 60075                                          1473.0
# 60076                                           759.0
#
#        Prestations familiales et sociales mensuelles moyennes (PFS)  Ri + PFS  \
# 0                                                  118.0                556.0
# 1                                                    0.0               1763.0
# 2                                                    0.0               1281.0
# 3                                                    0.0               1371.0
# 4                                                    0.0               3144.0
# ...                                                  ...                  ...
# 60072                                                0.0               2220.0
# 60073                                             1279.0               1279.0
# 60074                                              331.0               1776.0
# 60075                                                0.0               1473.0
# 60076                                                0.0                759.0
#
#        Ressources annuels ménage
# 0                         4730.4
# 1                        19040.4
# 2                        13834.8
# 3                        14806.8
# 4                        33955.2
# ...                          ...
# 60072                    23976.0
# 60073                        0.0
# 60074                    15606.0
# 60075                    15908.4
# 60076                     8197.2
#
# [60077 rows x 16 columns]

# %%
def abattement(compo_foyer):
    if compo_foyer=="Personne seule":
        return 4562
    elif compo_foyer=="Au moins 2 cotitulaires":
        return 6534
    elif (compo_foyer=="Au moins 2 cotitulaires avec une personne à charge" or compo_foyer=="Pers.seule avec 1 pers. à charge") :
        return 7793
    elif (compo_foyer=="Pers.seule avec 2 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 2 personnes à charge"):
        return 7969
    elif (compo_foyer=="Pers.seule avec 3 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 3 personnes à charge"):
        return 8274
    elif (compo_foyer=="Pers.seule avec 4 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 4 personnes à charge"):
        return 8581
    elif (compo_foyer=="Pers.seule avec 5 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 5 personnes à charge"):
        return 8886
    elif (compo_foyer=="Personne seule avec 6 pers. à charge ou plus" or compo_foyer=="Au moins 2 cotitulaires avec 6 personnes à charge ou plus"):
        return 9192

# %%
base['Abattement forfaitaire appliqué aux ressources du ménage '] = base['Composition foyer demandeur'].apply(abattement)
base
# Out:
#        Montant maxi (loyer+charges) supportable  \
# 0                                         300.0
# 1                                         400.0
# 2                                         300.0
# 3                                         700.0
# 4                                        1000.0
# ...                                         ...
# 60072                                       NaN
# 60073                                       NaN
# 60074                                       NaN
# 60075                                       NaN
# 60076                                       NaN
#
#        Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                               556.0                                 1.0
# 1                              1763.0                                 1.0
# 2                              1281.0                                 1.0
# 3                              3535.0                                 1.5
# 4                              3144.0                                 1.0
# ...                               ...                                 ...
# 60072                          1708.0                                 1.0
# 60073                          1279.0                                 1.9
# 60074                          1776.0                                 1.3
# 60075                          1273.0                                 1.0
# 60076                           759.0                                 1.0
#
#        Loyer montant mensuel       Composition foyer demandeur  \
# 0                      308.0                    Personne seule
# 1                      800.0                    Personne seule
# 2                      802.0                    Personne seule
# 3                      694.0           Au moins 2 cotitulaires
# 4                      878.0                    Personne seule
# ...                      ...                               ...
# 60072                  126.0                    Personne seule
# 60073                    0.0  Pers.seule avec 3 pers. à charge
# 60074                  328.0  Pers.seule avec 1 pers. à charge
# 60075                  450.0                    Personne seule
# 60076                  412.0                    Personne seule
#
#        Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                 0  175037900427000002
# 1                                               298  175118000728300002
# 2                                               372  211048217550092024
# 3                                               810  175108301617300002
# 4                                               626  175128420982700002
# ...                                             ...                 ...
# 60072                                           221  111011889159510122
# 60073                                           546  111011889407777067
# 60074                                           395  111011890348275B06
# 60075                                           270  111011891211794B02
# 60076                                           365  111011892001610103
#
#        Plafond loyer  Loyer éligible  \
# 0             295.05            0.00
# 1             295.05          295.05
# 2             295.05          295.05
# 3             355.85          355.85
# 4             295.05          295.05
# ...              ...             ...
# 60072         295.05          221.00
# 60073         518.86          518.86
# 60074         402.18          395.00
# 60075         295.05          270.00
# 60076         295.05          295.05
#
#        Montant forfaitaire au titre des charges  Unnamed: 0  RM Moyennes  \
# 0                                         53.67      130681        556.0
# 1                                         53.67      143374       1763.0
# 2                                         53.67      402468       1281.0
# 3                                         53.67      141654       1371.0
# 4                                         53.67      145079       3144.0
# ...                                         ...         ...          ...
# 60072                                     53.67      160165       1708.0
# 60073                                     90.15      160166       1279.0
# 60074                                     65.83       12689       1776.0
# 60075                                     53.67      546378       1273.0
# 60076                                     53.67      160168        759.0
#
#        Ressources imposables mensuelles moyennes (RI)  \
# 0                                               438.0
# 1                                              1763.0
# 2                                              1281.0
# 3                                              1371.0
# 4                                              3144.0
# ...                                               ...
# 60072                                          2220.0
# 60073                                             0.0
# 60074                                          1445.0
# 60075                                          1473.0
# 60076                                           759.0
#
#        Prestations familiales et sociales mensuelles moyennes (PFS)  Ri + PFS  \
# 0                                                  118.0                556.0
# 1                                                    0.0               1763.0
# 2                                                    0.0               1281.0
# 3                                                    0.0               1371.0
# 4                                                    0.0               3144.0
# ...                                                  ...                  ...
# 60072                                                0.0               2220.0
# 60073                                             1279.0               1279.0
# 60074                                              331.0               1776.0
# 60075                                                0.0               1473.0
# 60076                                                0.0                759.0
#
#        Ressources annuels ménage  \
# 0                         4730.4
# 1                        19040.4
# 2                        13834.8
# 3                        14806.8
# 4                        33955.2
# ...                          ...
# 60072                    23976.0
# 60073                        0.0
# 60074                    15606.0
# 60075                    15908.4
# 60076                     8197.2
#
#        Abattement forfaitaire appliqué aux ressources du ménage
# 0                                                   4562
# 1                                                   4562
# 2                                                   4562
# 3                                                   6534
# 4                                                   4562
# ...                                                  ...
# 60072                                               4562
# 60073                                               8274
# 60074                                               7793
# 60075                                               4562
# 60076                                               4562
#
# [60077 rows x 17 columns]

# %%
base['Participation minimale']=(base['Loyer éligible']+base['Montant forfaitaire au titre des charges'])*.085
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\662227790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['Participation minimale']=(base['Loyer éligible']+base['Montant forfaitaire au titre des charges'])*.085

# %%
base['35.02']=35.02
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\684511327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['35.02']=35.02

# %%
base['Participation minimale']=base[['Participation minimale','35.02']].max(axis=1)
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\1837699471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['Participation minimale']=base[['Participation minimale','35.02']].max(axis=1)

# %%
base
# Out:
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  Revenu imposable  \
# 0                                          53.67            6004.8
# 1                                          53.67           19040.4
# 2                                          53.67           13834.8
# 3                                          53.67           38178.0
# 4                                          53.67           33955.2
# ...                                          ...               ...
# 153709                                     53.67           14526.0
# 153710                                     53.67           10692.0
# 153711                                     53.67           19407.6
# 153712                                     77.99           37627.2
# 153713                                     65.83           24915.6
#
#         Abattement forfaitaire appliqué aux ressources du ménage         Rp  \
# 0                                                    4562          35.02000
# 1                                                    4562          35.02000
# 2                                                    4562          35.02000
# 3                                                    6534          35.02000
# 4                                                    4562          35.02000
# ...                                                   ...               ...
# 153709                                               6534          35.02000
# 153710                                               4562          35.02000
# 153711                                               4562          35.02000
# 153712                                               7969          35.95415
# 153713                                               7793          39.78085
#
#         35.02  Participation minimale
# 0       35.02                35.02000
# 1       35.02                35.02000
# 2       35.02                35.02000
# 3       35.02                35.02000
# 4       35.02                35.02000
# ...       ...                     ...
# 153709  35.02                35.02000
# 153710  35.02                35.02000
# 153711  35.02                35.02000
# 153712  35.02                35.95415
# 153713  35.02                39.78085
#
# [153714 rows x 15 columns]

# %%
base['0']=0
base["Rp"]=base['Revenu imposable']-base['Abattement forfaitaire appliqué aux ressources du ménage ']
base["Rp"]=base[['Rp','0']].max(axis=1)
base
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\3219225509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['0']=0
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\3219225509.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["Rp"]=base['Revenu imposable']-base['Abattement forfaitaire appliqué aux ressources du ménage ']
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\3219225509.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base["Rp"]=base[['Rp','0']].max(axis=1)
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  Revenu imposable  \
# 0                                          53.67            6004.8
# 1                                          53.67           19040.4
# 2                                          53.67           13834.8
# 3                                          53.67           38178.0
# 4                                          53.67           33955.2
# ...                                          ...               ...
# 153709                                     53.67           14526.0
# 153710                                     53.67           10692.0
# 153711                                     53.67           19407.6
# 153712                                     77.99           37627.2
# 153713                                     65.83           24915.6
#
#         Abattement forfaitaire appliqué aux ressources du ménage        Rp  \
# 0                                                    4562           1442.8
# 1                                                    4562          14478.4
# 2                                                    4562           9272.8
# 3                                                    6534          31644.0
# 4                                                    4562          29393.2
# ...                                                   ...              ...
# 153709                                               6534           7992.0
# 153710                                               4562           6130.0
# 153711                                               4562          14845.6
# 153712                                               7969          29658.2
# 153713                                               7793          17122.6
#
#         35.02  Participation minimale  0
# 0       35.02                35.02000  0
# 1       35.02                35.02000  0
# 2       35.02                35.02000  0
# 3       35.02                35.02000  0
# 4       35.02                35.02000  0
# ...       ...                     ... ..
# 153709  35.02                35.02000  0
# 153710  35.02                35.02000  0
# 153711  35.02                35.02000  0
# 153712  35.02                35.95415  0
# 153713  35.02                39.78085  0
#
# [153714 rows x 16 columns]

# %%
def tf(compo_foyer):
    if compo_foyer=="Personne seule":
        return 0.0283
    elif compo_foyer=="Au moins 2 cotitulaires":
        return 0.0315
    elif (compo_foyer=="Au moins 2 cotitulaires avec une personne à charge" or compo_foyer=="Pers.seule avec 1 pers. à charge") :
        return 0.0270
    elif (compo_foyer=="Pers.seule avec 2 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 2 personnes à charge"):
        return 0.0238
    elif (compo_foyer=="Pers.seule avec 3 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 3 personnes à charge"):
        return 0.0201
    elif (compo_foyer=="Pers.seule avec 4 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 4 personnes à charge"):
        return 0.0185
    elif (compo_foyer=="Pers.seule avec 5 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 5 personnes à charge"):
        return 0.0185-0.0006
    elif (compo_foyer=="Personne seule avec 6 pers. à charge ou plus" or compo_foyer=="Au moins 2 cotitulaires avec 6 personnes à charge ou plus"):
        return 0.0185-0.0006-0.0006

# %%
base['Taux fonction de la taille de la famille'] = base['Composition foyer demandeur'].apply(tf)
base
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\2851108637.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['Taux fonction de la taille de la famille'] = base['Composition foyer demandeur'].apply(tf)
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  Revenu imposable  \
# 0                                          53.67            6004.8
# 1                                          53.67           19040.4
# 2                                          53.67           13834.8
# 3                                          53.67           38178.0
# 4                                          53.67           33955.2
# ...                                          ...               ...
# 153709                                     53.67           14526.0
# 153710                                     53.67           10692.0
# 153711                                     53.67           19407.6
# 153712                                     77.99           37627.2
# 153713                                     65.83           24915.6
#
#         Abattement forfaitaire appliqué aux ressources du ménage        Rp  \
# 0                                                    4562           1442.8
# 1                                                    4562          14478.4
# 2                                                    4562           9272.8
# 3                                                    6534          31644.0
# 4                                                    4562          29393.2
# ...                                                   ...              ...
# 153709                                               6534           7992.0
# 153710                                               4562           6130.0
# 153711                                               4562          14845.6
# 153712                                               7969          29658.2
# 153713                                               7793          17122.6
#
#         35.02  Participation minimale  0  \
# 0       35.02                35.02000  0
# 1       35.02                35.02000  0
# 2       35.02                35.02000  0
# 3       35.02                35.02000  0
# 4       35.02                35.02000  0
# ...       ...                     ... ..
# 153709  35.02                35.02000  0
# 153710  35.02                35.02000  0
# 153711  35.02                35.02000  0
# 153712  35.02                35.95415  0
# 153713  35.02                39.78085  0
#
#         Taux fonction de la taille de la famille
# 0                                         0.0283
# 1                                         0.0283
# 2                                         0.0283
# 3                                         0.0315
# 4                                         0.0283
# ...                                          ...
# 153709                                    0.0315
# 153710                                    0.0283
# 153711                                    0.0283
# 153712                                    0.0238
# 153713                                    0.0270
#
# [153714 rows x 17 columns]

# %%
def lr(compo_foyer):
    if compo_foyer=="Personne seule":
        return 257.14
    elif compo_foyer=="Au moins 2 cotitulaires":
        return 314.74
    elif (compo_foyer=="Au moins 2 cotitulaires avec une personne à charge" or compo_foyer=="Pers.seule avec 1 pers. à charge") :
        return 354.17
    elif (compo_foyer=="Pers.seule avec 2 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 2 personnes à charge"):
        return 354.17+51.54
    elif (compo_foyer=="Pers.seule avec 3 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 3 personnes à charge"):
        return 354.17+51.54+51.54
    elif (compo_foyer=="Pers.seule avec 4 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 4 personnes à charge"):
        return 17+51.54+51.54+51.54
    elif (compo_foyer=="Pers.seule avec 5 pers. à charge" or compo_foyer=="Au moins 2 cotitulaires avec 5 personnes à charge"):
        return 354.17+51.54+51.54+51.54+51.54
    elif (compo_foyer=="Personne seule avec 6 pers. à charge ou plus" or compo_foyer=="Au moins 2 cotitulaires avec 6 personnes à charge ou plus"):
        return 354.17+51.54+51.54+51.54+51.54+51.54

# %%
base['Loyer de référence'] = base['Composition foyer demandeur'].apply(lr)
base
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\2069521994.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['Loyer de référence'] = base['Composition foyer demandeur'].apply(lr)
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  Revenu imposable  \
# 0                                          53.67            6004.8
# 1                                          53.67           19040.4
# 2                                          53.67           13834.8
# 3                                          53.67           38178.0
# 4                                          53.67           33955.2
# ...                                          ...               ...
# 153709                                     53.67           14526.0
# 153710                                     53.67           10692.0
# 153711                                     53.67           19407.6
# 153712                                     77.99           37627.2
# 153713                                     65.83           24915.6
#
#         Abattement forfaitaire appliqué aux ressources du ménage        Rp  \
# 0                                                    4562           1442.8
# 1                                                    4562          14478.4
# 2                                                    4562           9272.8
# 3                                                    6534          31644.0
# 4                                                    4562          29393.2
# ...                                                   ...              ...
# 153709                                               6534           7992.0
# 153710                                               4562           6130.0
# 153711                                               4562          14845.6
# 153712                                               7969          29658.2
# 153713                                               7793          17122.6
#
#         35.02  Participation minimale  0  \
# 0       35.02                35.02000  0
# 1       35.02                35.02000  0
# 2       35.02                35.02000  0
# 3       35.02                35.02000  0
# 4       35.02                35.02000  0
# ...       ...                     ... ..
# 153709  35.02                35.02000  0
# 153710  35.02                35.02000  0
# 153711  35.02                35.02000  0
# 153712  35.02                35.95415  0
# 153713  35.02                39.78085  0
#
#         Taux fonction de la taille de la famille  Loyer de référence
# 0                                         0.0283              257.14
# 1                                         0.0283              257.14
# 2                                         0.0283              257.14
# 3                                         0.0315              314.74
# 4                                         0.0283              257.14
# ...                                          ...                 ...
# 153709                                    0.0315              314.74
# 153710                                    0.0283              257.14
# 153711                                    0.0283              257.14
# 153712                                    0.0238              405.71
# 153713                                    0.0270              354.17
#
# [153714 rows x 18 columns]

# %%
base['Rapport RL']=base['Loyer éligible']/base['Loyer de référence']
base
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\2579458656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['Rapport RL']=base['Loyer éligible']/base['Loyer de référence']
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  Revenu imposable  \
# 0                                          53.67            6004.8
# 1                                          53.67           19040.4
# 2                                          53.67           13834.8
# 3                                          53.67           38178.0
# 4                                          53.67           33955.2
# ...                                          ...               ...
# 153709                                     53.67           14526.0
# 153710                                     53.67           10692.0
# 153711                                     53.67           19407.6
# 153712                                     77.99           37627.2
# 153713                                     65.83           24915.6
#
#         Abattement forfaitaire appliqué aux ressources du ménage        Rp  \
# 0                                                    4562           1442.8
# 1                                                    4562          14478.4
# 2                                                    4562           9272.8
# 3                                                    6534          31644.0
# 4                                                    4562          29393.2
# ...                                                   ...              ...
# 153709                                               6534           7992.0
# 153710                                               4562           6130.0
# 153711                                               4562          14845.6
# 153712                                               7969          29658.2
# 153713                                               7793          17122.6
#
#         35.02  Participation minimale  0  \
# 0       35.02                35.02000  0
# 1       35.02                35.02000  0
# 2       35.02                35.02000  0
# 3       35.02                35.02000  0
# 4       35.02                35.02000  0
# ...       ...                     ... ..
# 153709  35.02                35.02000  0
# 153710  35.02                35.02000  0
# 153711  35.02                35.02000  0
# 153712  35.02                35.95415  0
# 153713  35.02                39.78085  0
#
#         Taux fonction de la taille de la famille  Loyer de référence  \
# 0                                         0.0283              257.14
# 1                                         0.0283              257.14
# 2                                         0.0283              257.14
# 3                                         0.0315              314.74
# 4                                         0.0283              257.14
# ...                                          ...                 ...
# 153709                                    0.0315              314.74
# 153710                                    0.0283              257.14
# 153711                                    0.0283              257.14
# 153712                                    0.0238              405.71
# 153713                                    0.0270              354.17
#
#         Rapport RL
# 0         0.000000
# 1         1.147429
# 2         1.147429
# 3         1.130616
# 4         1.147429
# ...            ...
# 153709    0.861028
# 153710    1.022789
# 153711    1.147429
# 153712    0.850361
# 153713    1.135556
#
# [153714 rows x 19 columns]

# %%
base['C1']=0

def c1(rl):
    if rl>0.75:
        return 0.3
    else:
        return 0

base['C1'] = base['Rapport RL'].apply(c1)
base
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\285368886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['C1']=0
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\285368886.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['C1'] = base['Rapport RL'].apply(c1)
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  Revenu imposable  \
# 0                                          53.67            6004.8
# 1                                          53.67           19040.4
# 2                                          53.67           13834.8
# 3                                          53.67           38178.0
# 4                                          53.67           33955.2
# ...                                          ...               ...
# 153709                                     53.67           14526.0
# 153710                                     53.67           10692.0
# 153711                                     53.67           19407.6
# 153712                                     77.99           37627.2
# 153713                                     65.83           24915.6
#
#         Abattement forfaitaire appliqué aux ressources du ménage        Rp  \
# 0                                                    4562           1442.8
# 1                                                    4562          14478.4
# 2                                                    4562           9272.8
# 3                                                    6534          31644.0
# 4                                                    4562          29393.2
# ...                                                   ...              ...
# 153709                                               6534           7992.0
# 153710                                               4562           6130.0
# 153711                                               4562          14845.6
# 153712                                               7969          29658.2
# 153713                                               7793          17122.6
#
#         35.02  Participation minimale  0  \
# 0       35.02                35.02000  0
# 1       35.02                35.02000  0
# 2       35.02                35.02000  0
# 3       35.02                35.02000  0
# 4       35.02                35.02000  0
# ...       ...                     ... ..
# 153709  35.02                35.02000  0
# 153710  35.02                35.02000  0
# 153711  35.02                35.02000  0
# 153712  35.02                35.95415  0
# 153713  35.02                39.78085  0
#
#         Taux fonction de la taille de la famille  Loyer de référence  \
# 0                                         0.0283              257.14
# 1                                         0.0283              257.14
# 2                                         0.0283              257.14
# 3                                         0.0315              314.74
# 4                                         0.0283              257.14
# ...                                          ...                 ...
# 153709                                    0.0315              314.74
# 153710                                    0.0283              257.14
# 153711                                    0.0283              257.14
# 153712                                    0.0238              405.71
# 153713                                    0.0270              354.17
#
#         Rapport RL   C1
# 0         0.000000  0.0
# 1         1.147429  0.3
# 2         1.147429  0.3
# 3         1.130616  0.3
# 4         1.147429  0.3
# ...            ...  ...
# 153709    0.861028  0.3
# 153710    1.022789  0.3
# 153711    1.147429  0.3
# 153712    0.850361  0.3
# 153713    1.135556  0.3
#
# [153714 rows x 20 columns]

# %%
base['C2']=0

def c2(rl):
    if rl>0.45 and rl<=0.75 :
        return 0.0045
    elif rl>0.75:
        return 0.0068
    else:
        return 0

base['C2'] = base['Rapport RL'].apply(c2)
base
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\1269860709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['C2']=0
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\1269860709.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['C2'] = base['Rapport RL'].apply(c2)
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  ...  \
# 0                                          53.67  ...
# 1                                          53.67  ...
# 2                                          53.67  ...
# 3                                          53.67  ...
# 4                                          53.67  ...
# ...                                          ...  ...
# 153709                                     53.67  ...
# 153710                                     53.67  ...
# 153711                                     53.67  ...
# 153712                                     77.99  ...
# 153713                                     65.83  ...
#
#         Abattement forfaitaire appliqué aux ressources du ménage        Rp  \
# 0                                                    4562           1442.8
# 1                                                    4562          14478.4
# 2                                                    4562           9272.8
# 3                                                    6534          31644.0
# 4                                                    4562          29393.2
# ...                                                   ...              ...
# 153709                                               6534           7992.0
# 153710                                               4562           6130.0
# 153711                                               4562          14845.6
# 153712                                               7969          29658.2
# 153713                                               7793          17122.6
#
#         35.02  Participation minimale  0  \
# 0       35.02                35.02000  0
# 1       35.02                35.02000  0
# 2       35.02                35.02000  0
# 3       35.02                35.02000  0
# 4       35.02                35.02000  0
# ...       ...                     ... ..
# 153709  35.02                35.02000  0
# 153710  35.02                35.02000  0
# 153711  35.02                35.02000  0
# 153712  35.02                35.95415  0
# 153713  35.02                39.78085  0
#
#         Taux fonction de la taille de la famille  Loyer de référence  \
# 0                                         0.0283              257.14
# 1                                         0.0283              257.14
# 2                                         0.0283              257.14
# 3                                         0.0315              314.74
# 4                                         0.0283              257.14
# ...                                          ...                 ...
# 153709                                    0.0315              314.74
# 153710                                    0.0283              257.14
# 153711                                    0.0283              257.14
# 153712                                    0.0238              405.71
# 153713                                    0.0270              354.17
#
#         Rapport RL   C1      C2
# 0         0.000000  0.0  0.0000
# 1         1.147429  0.3  0.0068
# 2         1.147429  0.3  0.0068
# 3         1.130616  0.3  0.0068
# 4         1.147429  0.3  0.0068
# ...            ...  ...     ...
# 153709    0.861028  0.3  0.0068
# 153710    1.022789  0.3  0.0068
# 153711    1.147429  0.3  0.0068
# 153712    0.850361  0.3  0.0068
# 153713    1.135556  0.3  0.0068
#
# [153714 rows x 21 columns]

# %%
base['C3']=0

def c3(rl):
    if rl>0.45 and rl<=0.75 :
        return 0.45
    elif rl>0.75:
        return 0.75
    else:
        return 0

base['C3'] = base['Rapport RL'].apply(c3)
base
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\2196040518.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['C3']=0
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\2196040518.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['C3'] = base['Rapport RL'].apply(c3)
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  ...       Rp  35.02  \
# 0                                          53.67  ...   1442.8  35.02
# 1                                          53.67  ...  14478.4  35.02
# 2                                          53.67  ...   9272.8  35.02
# 3                                          53.67  ...  31644.0  35.02
# 4                                          53.67  ...  29393.2  35.02
# ...                                          ...  ...      ...    ...
# 153709                                     53.67  ...   7992.0  35.02
# 153710                                     53.67  ...   6130.0  35.02
# 153711                                     53.67  ...  14845.6  35.02
# 153712                                     77.99  ...  29658.2  35.02
# 153713                                     65.83  ...  17122.6  35.02
#
#         Participation minimale  0  Taux fonction de la taille de la famille  \
# 0                     35.02000  0                                    0.0283
# 1                     35.02000  0                                    0.0283
# 2                     35.02000  0                                    0.0283
# 3                     35.02000  0                                    0.0315
# 4                     35.02000  0                                    0.0283
# ...                        ... ..                                       ...
# 153709                35.02000  0                                    0.0315
# 153710                35.02000  0                                    0.0283
# 153711                35.02000  0                                    0.0283
# 153712                35.95415  0                                    0.0238
# 153713                39.78085  0                                    0.0270
#
#         Loyer de référence  Rapport RL   C1      C2    C3
# 0                   257.14    0.000000  0.0  0.0000  0.00
# 1                   257.14    1.147429  0.3  0.0068  0.75
# 2                   257.14    1.147429  0.3  0.0068  0.75
# 3                   314.74    1.130616  0.3  0.0068  0.75
# 4                   257.14    1.147429  0.3  0.0068  0.75
# ...                    ...         ...  ...     ...   ...
# 153709              314.74    0.861028  0.3  0.0068  0.75
# 153710              257.14    1.022789  0.3  0.0068  0.75
# 153711              257.14    1.147429  0.3  0.0068  0.75
# 153712              405.71    0.850361  0.3  0.0068  0.75
# 153713              354.17    1.135556  0.3  0.0068  0.75
#
# [153714 rows x 22 columns]

# %%
base['TL']=base['Rapport RL']-base['C3']
base['TL']= base['C2']*base['TL']
base['TL']= 0.0045*base['C1'] + base['TL']

#TL=0.0045*C1+C2*(RL-C3)
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\3216224358.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['TL']=base['Rapport RL']-base['C3']
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\3216224358.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['TL']= base['C2']*base['TL']
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\3216224358.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['TL']= 0.0045*base['C1'] + base['TL']

# %%
base
# Out:
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  ...  Participation minimale  \
# 0                                          53.67  ...                35.02000
# 1                                          53.67  ...                35.02000
# 2                                          53.67  ...                35.02000
# 3                                          53.67  ...                35.02000
# 4                                          53.67  ...                35.02000
# ...                                          ...  ...                     ...
# 153709                                     53.67  ...                35.02000
# 153710                                     53.67  ...                35.02000
# 153711                                     53.67  ...                35.02000
# 153712                                     77.99  ...                35.95415
# 153713                                     65.83  ...                39.78085
#
#         0  Taux fonction de la taille de la famille  Loyer de référence  \
# 0       0                                    0.0283              257.14
# 1       0                                    0.0283              257.14
# 2       0                                    0.0283              257.14
# 3       0                                    0.0315              314.74
# 4       0                                    0.0283              257.14
# ...    ..                                       ...                 ...
# 153709  0                                    0.0315              314.74
# 153710  0                                    0.0283              257.14
# 153711  0                                    0.0283              257.14
# 153712  0                                    0.0238              405.71
# 153713  0                                    0.0270              354.17
#
#         Rapport RL   C1      C2    C3        TL  \
# 0         0.000000  0.0  0.0000  0.00  0.000000
# 1         1.147429  0.3  0.0068  0.75  0.004053
# 2         1.147429  0.3  0.0068  0.75  0.004053
# 3         1.130616  0.3  0.0068  0.75  0.003938
# 4         1.147429  0.3  0.0068  0.75  0.004053
# ...            ...  ...     ...   ...       ...
# 153709    0.861028  0.3  0.0068  0.75  0.002105
# 153710    1.022789  0.3  0.0068  0.75  0.003205
# 153711    1.147429  0.3  0.0068  0.75  0.004053
# 153712    0.850361  0.3  0.0068  0.75  0.002032
# 153713    1.135556  0.3  0.0068  0.75  0.003972
#
#         Taux de prise en compte des ressources des ménages (Tp)
# 0                                                0.028300
# 1                                                0.032353
# 2                                                0.032353
# 3                                                0.035438
# 4                                                0.032353
# ...                                                   ...
# 153709                                           0.033605
# 153710                                           0.031505
# 153711                                           0.032353
# 153712                                           0.025832
# 153713                                           0.030972
#
# [153714 rows x 24 columns]

# %%
base['Taux de prise en compte des ressources des ménages (Tp)']=base['TL']+ base['Taux fonction de la taille de la famille']
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\300639711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['Participation personnelle du ménage']=base['Taux de prise en compte des ressources des ménages (Tp)']*base['Rp']
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\300639711.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['Participation personnelle du ménage']=base['Participation personnelle du ménage'] + base['Participation minimale']
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  ...  \
# 0                                          53.67  ...
# 1                                          53.67  ...
# 2                                          53.67  ...
# 3                                          53.67  ...
# 4                                          53.67  ...
# ...                                          ...  ...
# 153709                                     53.67  ...
# 153710                                     53.67  ...
# 153711                                     53.67  ...
# 153712                                     77.99  ...
# 153713                                     65.83  ...
#
#         Taux fonction de la taille de la famille  Loyer de référence  \
# 0                                         0.0283              257.14
# 1                                         0.0283              257.14
# 2                                         0.0283              257.14
# 3                                         0.0315              314.74
# 4                                         0.0283              257.14
# ...                                          ...                 ...
# 153709                                    0.0315              314.74
# 153710                                    0.0283              257.14
# 153711                                    0.0283              257.14
# 153712                                    0.0238              405.71
# 153713                                    0.0270              354.17
#
#         Rapport RL   C1      C2    C3        TL  \
# 0         0.000000  0.0  0.0000  0.00  0.000000
# 1         1.147429  0.3  0.0068  0.75  0.004053
# 2         1.147429  0.3  0.0068  0.75  0.004053
# 3         1.130616  0.3  0.0068  0.75  0.003938
# 4         1.147429  0.3  0.0068  0.75  0.004053
# ...            ...  ...     ...   ...       ...
# 153709    0.861028  0.3  0.0068  0.75  0.002105
# 153710    1.022789  0.3  0.0068  0.75  0.003205
# 153711    1.147429  0.3  0.0068  0.75  0.004053
# 153712    0.850361  0.3  0.0068  0.75  0.002032
# 153713    1.135556  0.3  0.0068  0.75  0.003972
#
#         Taux de prise en compte des ressources des ménages (Tp)  \
# 0                                                0.028300
# 1                                                0.032353
# 2                                                0.032353
# 3                                                0.035438
# 4                                                0.032353
# ...                                                   ...
# 153709                                           0.033605
# 153710                                           0.031505
# 153711                                           0.032353
# 153712                                           0.025832
# 153713                                           0.030972
#
#         Participation personnelle du ménage         APL
# 0                                 75.851240  -22.181240
# 1                                503.432726 -154.712726
# 2                                335.018448   13.701552
# 3                               1156.425992 -746.905992
# 4                                985.964092 -637.244092
# ...                                     ...         ...
# 153709                           303.591091   21.078909
# 153710                           228.145443   88.524557
# 153711                           515.312571 -166.592571
# 153712                           802.098280 -379.108280
# 153713                           570.098307 -102.088307
#
# [153714 rows x 26 columns]

# %%
base['Participation personnelle du ménage']=base['Taux de prise en compte des ressources des ménages (Tp)']*base['Rp']
base['Participation personnelle du ménage']=base['Participation personnelle du ménage'] + base['Participation minimale']
base
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\3801738382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['APL']=base['Loyer éligible'] + base['Montant forfaitaire au titre des charges']-base['Participation personnelle du ménage']

# %%
base['APL']=base['Loyer éligible'] + base['Montant forfaitaire au titre des charges']-base['Participation personnelle du ménage']
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\3801738382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['APL']=base['Loyer éligible'] + base['Montant forfaitaire au titre des charges']-base['Participation personnelle du ménage']

# %%
base['P1']=3.4*base['Montant loyer mensuel du logement attribué\n']
base['P2']=4*base['Montant loyer mensuel du logement attribué\n']
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\679197961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['P1']=3.4*base['Montant loyer mensuel du logement attribué\n']
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\679197961.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['P2']=4*base['Montant loyer mensuel du logement attribué\n']

# %%
base['APL1']=(base['P2']*base['Montant loyer mensuel du logement attribué\n']-base['Loyer éligible'])/((base['P2']-base['P1'])*base['Montant loyer mensuel du logement attribué\n'])*base['APL']
#replace APL=(P2*Lp-L)/((P2-P1)*Lp)*APL if L>P1 & L<=P2
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_17184\837855797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base['APL1']=(base['P2']*base['Montant loyer mensuel du logement attribué\n']-base['Loyer éligible'])/((base['P2']-base['P1'])*base['Montant loyer mensuel du logement attribué\n'])*base['APL']

# %%
base
# Out:
#         Montant maxi (loyer+charges) supportable  \
# 0                                          300.0
# 1                                          400.0
# 2                                          300.0
# 3                                          700.0
# 4                                         1000.0
# ...                                          ...
# 153709                                     354.0
# 153710                                     400.0
# 153711                                     472.0
# 153712                                     800.0
# 153713                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                                556.0                                 1.0
# 1                               1763.0                                 1.0
# 2                               1281.0                                 1.0
# 3                               3535.0                                 1.5
# 4                               3144.0                                 1.0
# ...                                ...                                 ...
# 153709                          1345.0                                 1.5
# 153710                           990.0                                 1.0
# 153711                          1797.0                                 1.0
# 153712                          3484.0                                 2.1
# 153713                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       308.0
# 1                       800.0
# 2                       802.0
# 3                       694.0
# 4                       878.0
# ...                       ...
# 153709                  469.0
# 153710                  388.0
# 153711                  560.0
# 153712                  592.0
# 153713                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                          Personne seule
# 3                                 Au moins 2 cotitulaires
# 4                                          Personne seule
# ...                                                   ...
# 153709                            Au moins 2 cotitulaires
# 153710                                     Personne seule
# 153711                                     Personne seule
# 153712  Au moins 2 cotitulaires avec 2 personnes à charge
# 153713  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                  0  175037900427000002
# 1                                                298  175118000728300002
# 2                                                372  211048217550092024
# 3                                                810  175108301617300002
# 4                                                626  175128420982700002
# ...                                              ...                 ...
# 153709                                           271  1111218129847GDPUB
# 153710                                           263  111121812788778498
# 153711                                           472  111121812792310122
# 153712                                           345  111121813038177438
# 153713                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05            0.00
# 1              295.05          295.05
# 2              295.05          295.05
# 3              355.85          355.85
# 4              295.05          295.05
# ...               ...             ...
# 153709         355.85          271.00
# 153710         295.05          263.00
# 153711         295.05          295.05
# 153712         460.52          345.00
# 153713         402.18          402.18
#
#         Montant forfaitaire au titre des charges  ...   C1      C2    C3  \
# 0                                          53.67  ...  0.0  0.0000  0.00
# 1                                          53.67  ...  0.3  0.0068  0.75
# 2                                          53.67  ...  0.3  0.0068  0.75
# 3                                          53.67  ...  0.3  0.0068  0.75
# 4                                          53.67  ...  0.3  0.0068  0.75
# ...                                          ...  ...  ...     ...   ...
# 153709                                     53.67  ...  0.3  0.0068  0.75
# 153710                                     53.67  ...  0.3  0.0068  0.75
# 153711                                     53.67  ...  0.3  0.0068  0.75
# 153712                                     77.99  ...  0.3  0.0068  0.75
# 153713                                     65.83  ...  0.3  0.0068  0.75
#
#               TL  Taux de prise en compte des ressources des ménages (Tp)  \
# 0       0.000000                                           0.028300
# 1       0.004053                                           0.032353
# 2       0.004053                                           0.032353
# 3       0.003938                                           0.035438
# 4       0.004053                                           0.032353
# ...          ...                                                ...
# 153709  0.002105                                           0.033605
# 153710  0.003205                                           0.031505
# 153711  0.004053                                           0.032353
# 153712  0.002032                                           0.025832
# 153713  0.003972                                           0.030972
#
#         Participation personnelle du ménage         APL      P1    P2  \
# 0                                 75.851240  -22.181240     0.0     0
# 1                                503.432726 -154.712726  1013.2  1192
# 2                                335.018448   13.701552  1264.8  1488
# 3                               1156.425992 -746.905992  2754.0  3240
# 4                                985.964092 -637.244092  2128.4  2504
# ...                                     ...         ...     ...   ...
# 153709                           303.591091   21.078909   921.4  1084
# 153710                           228.145443   88.524557   894.2  1052
# 153711                           515.312571 -166.592571  1604.8  1888
# 153712                           802.098280 -379.108280  1173.0  1380
# 153713                           570.098307 -102.088307  1485.8  1748
#
#                APL1
# 0               NaN
# 1      -1030.561455
# 2         91.294993
# 3      -4978.698111
# 4      -4247.494292
# ...             ...
# 153709   140.396420
# 153710   589.602724
# 153711 -1110.249423
# 153712 -2525.557094
# 153713  -680.230385
#
# [153714 rows x 29 columns]

# %%
base1=base.dropna()
base1 = base1.reset_index(drop=True)
base1
# Out:
#         Montant maxi (loyer+charges) supportable  \
# 0                                          400.0
# 1                                          300.0
# 2                                          700.0
# 3                                         1000.0
# 4                                            0.0
# ...                                          ...
# 113706                                     354.0
# 113707                                     400.0
# 113708                                     472.0
# 113709                                     800.0
# 113710                                     500.0
#
#         Ressources mensuelles du foyer  Nb unités de consommation du foyer  \
# 0                               1763.0                                 1.0
# 1                               1281.0                                 1.0
# 2                               3535.0                                 1.5
# 3                               3144.0                                 1.0
# 4                               1819.0                                 1.0
# ...                                ...                                 ...
# 113706                          1345.0                                 1.5
# 113707                           990.0                                 1.0
# 113708                          1797.0                                 1.0
# 113709                          3484.0                                 2.1
# 113710                          2307.0                                 1.8
#
#         Loyer montant mensuel  \
# 0                       800.0
# 1                       802.0
# 2                       694.0
# 3                       878.0
# 4                       679.0
# ...                       ...
# 113706                  469.0
# 113707                  388.0
# 113708                  560.0
# 113709                  592.0
# 113710                  460.0
#
#                               Composition foyer demandeur  \
# 0                                          Personne seule
# 1                                          Personne seule
# 2                                 Au moins 2 cotitulaires
# 3                                          Personne seule
# 4                                          Personne seule
# ...                                                   ...
# 113706                            Au moins 2 cotitulaires
# 113707                                     Personne seule
# 113708                                     Personne seule
# 113709  Au moins 2 cotitulaires avec 2 personnes à charge
# 113710  Au moins 2 cotitulaires avec une personne à ch...
#
#         Montant loyer mensuel du logement attribué\n       Numéro Unique  \
# 0                                                298  175118000728300002
# 1                                                372  211048217550092024
# 2                                                810  175108301617300002
# 3                                                626  175128420982700002
# 4                                                441  175018604471600002
# ...                                              ...                 ...
# 113706                                           271  1111218129847GDPUB
# 113707                                           263  111121812788778498
# 113708                                           472  111121812792310122
# 113709                                           345  111121813038177438
# 113710                                           437  111121813209910389
#
#         Plafond loyer  Loyer éligible  \
# 0              295.05          295.05
# 1              295.05          295.05
# 2              355.85          355.85
# 3              295.05          295.05
# 4              295.05          295.05
# ...               ...             ...
# 113706         355.85          271.00
# 113707         295.05          263.00
# 113708         295.05          295.05
# 113709         460.52          345.00
# 113710         402.18          402.18
#
#         Montant forfaitaire au titre des charges  ...   C1      C2    C3  \
# 0                                          53.67  ...  0.3  0.0068  0.75
# 1                                          53.67  ...  0.3  0.0068  0.75
# 2                                          53.67  ...  0.3  0.0068  0.75
# 3                                          53.67  ...  0.3  0.0068  0.75
# 4                                          53.67  ...  0.3  0.0068  0.75
# ...                                          ...  ...  ...     ...   ...
# 113706                                     53.67  ...  0.3  0.0068  0.75
# 113707                                     53.67  ...  0.3  0.0068  0.75
# 113708                                     53.67  ...  0.3  0.0068  0.75
# 113709                                     77.99  ...  0.3  0.0068  0.75
# 113710                                     65.83  ...  0.3  0.0068  0.75
#
#               TL  Taux de prise en compte des ressources des ménages (Tp)  \
# 0       0.004053                                           0.032353
# 1       0.004053                                           0.032353
# 2       0.003938                                           0.035438
# 3       0.004053                                           0.032353
# 4       0.004053                                           0.032353
# ...          ...                                                ...
# 113706  0.002105                                           0.033605
# 113707  0.003205                                           0.031505
# 113708  0.004053                                           0.032353
# 113709  0.002032                                           0.025832
# 113710  0.003972                                           0.030972
#
#         Participation personnelle du ménage         APL      P1    P2  \
# 0                                503.432726 -154.712726  1013.2  1192
# 1                                335.018448   13.701552  1264.8  1488
# 2                               1156.425992 -746.905992  2754.0  3240
# 3                                985.964092 -637.244092  2128.4  2504
# 4                                522.999530 -174.279530  1499.4  1764
# ...                                     ...         ...     ...   ...
# 113706                           303.591091   21.078909   921.4  1084
# 113707                           228.145443   88.524557   894.2  1052
# 113708                           515.312571 -166.592571  1604.8  1888
# 113709                           802.098280 -379.108280  1173.0  1380
# 113710                           570.098307 -102.088307  1485.8  1748
#
#                APL1
# 0      -1030.561455
# 1         91.294993
# 2      -4978.698111
# 3      -4247.494292
# 4      -1161.422864
# ...             ...
# 113706   140.396420
# 113707   589.602724
# 113708 -1110.249423
# 113709 -2525.557094
# 113710  -680.230385
#
# [113711 rows x 29 columns]

# %%
base1.rename(columns={'Montant loyer mensuel du logement attribué\n': 'Montant loyer mensuel du logement attribue'}, inplace=True)

# %%
def apl(l):
    if l>base1[base1['P1']] and l<=base1[base1['P2']] :
        return base1['APL1']
    elif l>base1[base1['P2'] * base1['Montant loyer mensuel du logement attribue']]:
        return 0
    else:
        return 0

base1['APL'] = base1['Montant loyer mensuel du logement attribue'].apply(apl)
base1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [90], in <cell line: 9>()
#       6     else:
#       7         return 0
# ----> 9 base1['APL'] = base1['Montant loyer mensuel du logement attribue'].apply(apl)
#      10 base1
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [90], in apl(l)
#       1 def apl(l):
# ----> 2     if l>base1[base1['P1']] and l<=base1[base1['P2']] :
#       3         return base1['APL1']
#       4     elif l>base1[base1['P2'] * base1['Montant loyer mensuel du logement attribue']]:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Float64Index([1013.1999999999999,             1264.8,             2754.0,\n                          2128.4, 1499.3999999999999, 2369.7999999999997,\n              2216.7999999999997, 1414.3999999999999,             2631.6,\n                          3070.2,\n              ...\n                          2142.0,            33996.6,             1003.0,\n                          2400.4,             2713.2,              921.4,\n               894.1999999999999,             1604.8,             1173.0,\n                          1485.8],\n             dtype='float64', length=113711)] are in the [columns]"

# %%
#replace APL=(P2*Lp-L)/((P2-P1)*Lp)*APL if L>P1 & L<=P2
def apl(l):
    if base[l] > base[base['P1']] and l <= base[base['P2']]:
        return base['APL1']
    elif base[l] > base[base['P2'] * base['Montant loyer mensuel du logement attribué\n']]:
        return 0
    else:
        return 0


base['APL'] = base['Montant loyer mensuel du logement attribué\n'].apply(apl)
base
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [82], in <cell line: 11>()
#       7     else:
#       8         return 0
# ---> 11 base['APL'] = base['Montant loyer mensuel du logement attribué\n'].apply(apl)
#      12 base
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [82], in apl(l)
#       2 def apl(l):
# ----> 3     if base[l] > base[base['P1']] and l <= base[base['P2']]:
#       4         return base['APL1']
#       5     elif base[l] > base[base['P2'] * base['Montant loyer mensuel du logement attribué\n']]:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 0

# %%
#replace APL=(P2*Lp-L)/((P2-P1)*Lp)*APL if L>P1 & L<=P2
def apl(l):
    if l > base[base['P1']] and l <= base[base['P2']]:
        return base['APL1']
    elif l > base[base['P2'] * base['Montant loyer mensuel du logement attribué\n']]:
        return 0
    else:
        return 0


base['APL'] = base['Montant loyer mensuel du logement attribué\n'].apply(apl)
base
