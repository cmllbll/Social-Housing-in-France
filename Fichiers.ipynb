# %%
import pandas as pd
import numpy as np

# %%
dfd = pd.read_csv(r'C:\Users\arceb\PycharmProjects\pythonProject/Paris.csv', index_col = 0)
dfd
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_40984\4054099379.py:1: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfd = pd.read_csv(r'C:\Users\arceb\PycharmProjects\pythonProject/Paris.csv', index_col = 0)
#              Numéro Unique  RM Moyennes  \
# 0       111011473621594041       1094.0
# 1       111011596527675056       1127.0
# 2       111011624892175056       1501.0
# 3       1110117567829GDPUB        674.0
# 4       1110117576292AL018       1410.0
# ...                    ...          ...
# 181616  175120708787700002        433.0
# 181617  175120725745300002       2415.0
# 181618  175120901070000002       1225.0
# 181619  175121022516400002       1535.0
# 181620  211011233353775B02        924.0
#
#         Ressources imposables mensuelles moyennes (RI)  \
# 0                                                105.0
# 1                                               1127.0
# ...

# %%
df = pd.DataFrame(pd.read_excel(r'C:\Users\arceb\PycharmProjects\pythonProject/DGALN.xlsx'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df = pd.DataFrame(pd.read_excel(r'C:\Users\arceb\PycharmProjects\pythonProject/DGALN.xlsx'))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
