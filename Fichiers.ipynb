# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Paris

# %%
dfd = pd.read_csv(r'C:\Users\arceb\PycharmProjects\pythonProject/Paris.csv', index_col = 0)
dfd=dfd.rename(columns={'Code INSEE commune logt souhaité': 'Code Géographique'})
dfd
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_40984\4287902780.py:1: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfd = pd.read_csv(r'C:\Users\arceb\PycharmProjects\pythonProject/Paris.csv', index_col = 0)
#              Numéro Unique  RM Moyennes  \
# 0       111011473621594041       1094.0
# 1       111011596527675056       1127.0
# 2       111011624892175056       1501.0
# 3       1110117567829GDPUB        674.0
# 4       1110117576292AL018       1410.0
# ...                    ...          ...
# 181616  175120708787700002        433.0
# 181617  175120725745300002       2415.0
# 181618  175120901070000002       1225.0
# 181619  175121022516400002       1535.0
# 181620  211011233353775B02        924.0
#
#         Ressources imposables mensuelles moyennes (RI)  \
# 0                                                105.0
# 1                                               1127.0
# ...

# %%
df['Code Géographique']=df['Code Géographique'].astype(str)
dfd['Code Géographique']=dfd['Code Géographique'].astype(int)

# %%
def code(commune):
    if commune>74999 and commune<=75999 :
        return 75056
    else :
        return commune


dfd['Code Géographique'] = dfd['Code Géographique'].apply(code)
dfd
# Out:
#              Numéro Unique  RM Moyennes  \
# 0       111011473621594041       1094.0
# 1       111011596527675056       1127.0
# 2       111011624892175056       1501.0
# 3       1110117567829GDPUB        674.0
# 4       1110117576292AL018       1410.0
# ...                    ...          ...
# 181616  175120708787700002        433.0
# 181617  175120725745300002       2415.0
# 181618  175120901070000002       1225.0
# 181619  175121022516400002       1535.0
# 181620  211011233353775B02        924.0
#
#         Ressources imposables mensuelles moyennes (RI)  \
# 0                                                105.0
# 1                                               1127.0
# 2                                                  0.0
# 3                                                  0.0
# 4                                               1410.0
# ...                                                ...
# 181616                                             0.0
# ...

# %%
df = pd.DataFrame(pd.read_excel(r'C:\Users\arceb\PycharmProjects\pythonProject/DGALN.xls'))
df
# Out:
#       Code Géographique    Libellé de la commune  \
# 0                 01001  L'Abergement-Clémenciat
# 1                 01002    L'Abergement-de-Varey
# 2                 01004        Ambérieu-en-Bugey
# 3                 01005      Ambérieux-en-Dombes
# 4                 01006                  Ambléon
# ...                 ...                      ...
# 36676             97613            M'Tsangamouji
# 36677             97614                 Ouangani
# 36678             97615                 Pamandzi
# 36679             97616                     Sada
# 36680             97617                 Tsingoni
#
#       Zonage I/II/III\nArrêté du 17 mars 1978 relatif au classement des communes par zones geographiques
# 0                                                     03
# 1                                                     03
# 2                                                     03
# 3                                                     03
# ...

# %%
df[df['Code Géographique']=='2A001']
# Out:
#       Code Géographique Libellé de la commune  \
# 11155             2A001                   Afa
#
#       Zonage I/II/III\nArrêté du 17 mars 1978 relatif au classement des communes par zones geographiques
# 11155                                                 02

# %%
df['Code Géographique']=df['Code Géographique'].astype(str)
dfd['Code Géographique']=dfd['Code Géographique'].astype(str)

# %%
base= dfd.merge(df, on='Code Géographique', how='inner')
base
# Out:
#              Numéro Unique  RM Moyennes  \
# 0       111011473621594041       1094.0
# 1       111011596527675056       1127.0
# 2       111011624892175056       1501.0
# 3       1110117567829GDPUB        674.0
# 4       1110117576292AL018       1410.0
# ...                    ...          ...
# 181616  175120708787700002        433.0
# 181617  175120725745300002       2415.0
# 181618  175120901070000002       1225.0
# 181619  175121022516400002       1535.0
# 181620  211011233353775B02        924.0
#
#         Ressources imposables mensuelles moyennes (RI)  \
# 0                                                105.0
# 1                                               1127.0
# 2                                                  0.0
# 3                                                  0.0
# 4                                               1410.0
# ...                                                ...
# 181616                                             0.0
# ...

# %%
file_name = 'Paris_final.csv'
base.to_csv(file_name)

# %% [markdown]
# ## Lyon

# %%
dfd = pd.read_csv(r'C:\Users\arceb\PycharmProjects\pythonProject/Lyon.csv', index_col = 0)
dfd=dfd.rename(columns={'Code INSEE commune logt souhaité': 'Code Géographique'})
dfd
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_40984\3604640403.py:1: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfd = pd.read_csv(r'C:\Users\arceb\PycharmProjects\pythonProject/Lyon.csv', index_col = 0)
#             Numéro Unique  RM Moyennes  \
# 0      069011102052311161        809.0
# 1      069011614196011128        524.0
# 2      069011614446911204       2180.0
# 3      0690117045253GDPUB       1467.0
# 4      0690117046129FCR69        828.0
# ...                   ...          ...
# 62064  0691216041995GDPUB       2089.0
# 62065  0691216042374FCR69       1176.0
# 62066  0691216042650GDPUB        962.0
# 62067  0691217089529FCR69       1057.0
# 62068  0691217090418FCR69       1340.0
#
#        Ressources imposables mensuelles moyennes (RI)  \
# 0                                               700.0
# 1                                                 0.0
# 2                                              2050.0
# ...

# %%
dfd['Code Géographique']=dfd['Code Géographique'].astype(int)

# %%
def code1(commune):
    if commune>=69381 and commune<=69389 :
        return 69123
    else :
        return commune


dfd['Code Géographique'] = dfd['Code Géographique'].apply(code1)
dfd
# Out:
#             Numéro Unique  RM Moyennes  \
# 0      069011102052311161        809.0
# 1      069011614196011128        524.0
# 2      069011614446911204       2180.0
# 3      0690117045253GDPUB       1467.0
# 4      0690117046129FCR69        828.0
# ...                   ...          ...
# 62064  0691216041995GDPUB       2089.0
# 62065  0691216042374FCR69       1176.0
# 62066  0691216042650GDPUB        962.0
# 62067  0691217089529FCR69       1057.0
# 62068  0691217090418FCR69       1340.0
#
#        Ressources imposables mensuelles moyennes (RI)  \
# 0                                               700.0
# 1                                                 0.0
# 2                                              2050.0
# 3                                              1467.0
# 4                                               236.0
# ...                                               ...
# 62064                                          2089.0
# ...

# %%
dfd['Code Géographique']=dfd['Code Géographique'].astype(str)
base= dfd.merge(df, on='Code Géographique', how='inner')
base
# Out:
#             Numéro Unique  RM Moyennes  \
# 0      069011102052311161        809.0
# 1      0690316005792FCR69       1163.0
# 2      0690417063596FCR69       1462.0
# 3      0690617067986GDPUB       1283.0
# 4      0690517064998GDPUB       1800.0
# ...                   ...          ...
# 62064  0691215001738FCR69       1384.0
# 62065  0691217089044FCR69       1400.0
# 62066  0690717069962GDPUB       1900.0
# 62067  0690817073543AL003       1650.0
# 62068  069121513858311189       1226.0
#
#        Ressources imposables mensuelles moyennes (RI)  \
# 0                                               700.0
# 1                                              1163.0
# 2                                              1462.0
# 3                                              1100.0
# 4                                              1800.0
# ...                                               ...
# 62064                                          1200.0
# ...

# %%
file_name = 'Lyon_final.csv'
base.to_csv(file_name)

# %% [markdown]
# ## Marseille

# %%
dfd = pd.read_csv(r'C:\Users\arceb\PycharmProjects\pythonProject/Marseille.csv', index_col = 0)
dfd=dfd.rename(columns={'Code INSEE commune logt souhaité': 'Code Géographique'})
dfd
# Out:
# C:\Users\arceb\AppData\Local\Temp\ipykernel_40984\2202805944.py:1: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfd = pd.read_csv(r'C:\Users\arceb\PycharmProjects\pythonProject/Marseille.csv', index_col = 0)
#             Numéro Unique  RM Moyennes  \
# 0      013011204268411400        830.0
# 1      013011204496911379        690.0
# 2      013011308057313103        598.0
# 3      013011412161111378        972.0
# 4      013011412266011378       1889.0
# ...                   ...          ...
# 74613  0131217301997GDPUB       1162.0
# 74614  0131217302048GDPUB        545.0
# 74615  0131217312848AL002       1486.0
# 74616  084021706603611409       1485.0
# 74617  0840717070307GDPUB          0.0
#
#        Ressources imposables mensuelles moyennes (RI)  \
# 0                                               830.0
# 1                                               690.0
# 2                                                 0.0
# ...

# %%
dfd['Code Géographique']=dfd['Code Géographique'].astype(int)

# %%
def code2(commune):
    if commune>=13201 and commune<=13216 :
        return 13055
    else :
        return commune


dfd['Code Géographique'] = dfd['Code Géographique'].apply(code2)
dfd
# Out:
#             Numéro Unique  RM Moyennes  \
# 0      013011204268411400        830.0
# 1      013011204496911379        690.0
# 2      013011308057313103        598.0
# 3      013011412161111378        972.0
# 4      013011412266011378       1889.0
# ...                   ...          ...
# 74613  0131217301997GDPUB       1162.0
# 74614  0131217302048GDPUB        545.0
# 74615  0131217312848AL002       1486.0
# 74616  084021706603611409       1485.0
# 74617  0840717070307GDPUB          0.0
#
#        Ressources imposables mensuelles moyennes (RI)  \
# 0                                               830.0
# 1                                               690.0
# 2                                                 0.0
# 3                                               972.0
# 4                                              1209.0
# ...                                               ...
# 74613                                          1162.0
# ...

# %%
dfd
dfd['Code Géographique'] = dfd['Code Géographique'].astype(str)
base = dfd.merge(df, on='Code Géographique', how='inner')
base
# Out:
#             Numéro Unique  RM Moyennes  \
# 0      013011204268411400        830.0
# 1      013021621166211404       1400.0
# 2      013061727648911378        470.0
# 3      0130617278415GDPUB       1376.0
# 4      0130617279644AG002       2337.0
# ...                   ...          ...
# 74613  013081728488811445        898.0
# 74614  013111625006913R03       1854.0
# 74615  0130716233378GDPUB        848.0
# 74616  013091414980411378       1410.0
# 74617  013091728922411391       1418.0
#
#        Ressources imposables mensuelles moyennes (RI)  \
# 0                                               830.0
# 1                                              1400.0
# 2                                                 0.0
# 3                                              1376.0
# 4                                              2143.0
# ...                                               ...
# 74613                                           898.0
# ...

# %%
file_name = 'Marseille_final.csv'
base.to_csv(file_name)
