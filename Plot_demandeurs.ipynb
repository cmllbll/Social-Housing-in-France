# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
RI_nuls = [13566, 16213, 18030, 12813]
PFS_nuls = [38719, 64839, 46470, 44174]
demandeurs = [77729, 114364, 90219, 80879]

# %%
index = ['Bouches-du-Rhône', 'Rhône-Alpes', 'Nord', 'Aquitaine']
df = pd.DataFrame({'RI non déclarés': RI_nuls,'PFS non déclarés': PFS_nuls, 'Nombre total de demandeurs':demandeurs}, index=index)
ax = df.plot.bar(rot=0)

# %%
ax.figure.savefig('demandeurs.pdf')
